# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.random.randn(3)
print(type(data))
print(data)
# Out:
# <class 'numpy.ndarray'>
# [-0.37016633 -0.00515892  0.87261852]

# %%
seri = pd.Series(data)
print(type(seri))
print(seri)
# Out:
# <class 'pandas.core.series.Series'>
# 0   -0.370166
# 1   -0.005159
# 2    0.872619
# dtype: float64

# %%
seri.plot()
# Out:
# <Axes: >
